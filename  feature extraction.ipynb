# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil\lab-customer-analysis-round-2\files_for_lab
#
# 08/08/2022  19:23    <DIR>          .
# 30/08/2022  15:50    <DIR>          ..
# 08/08/2022  19:23               273 about.md
# 08/08/2022  19:23    <DIR>          csv_files
# 08/08/2022  19:23    <DIR>          excel_files
#                1 File(s)            273 bytes
#                4 Dir(s)  405,368,061,952 bytes free

# %%
cd ..
# Out:
# C:\Users\tomil\lab-customer-analysis-round-2

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil\lab-customer-analysis-round-2
#
# 30/08/2022  15:50    <DIR>          .
# 22/11/2022  20:46    <DIR>          ..
# 08/08/2022  19:23    <DIR>          .github
# 30/08/2022  11:26    <DIR>          .ipynb_checkpoints
# 08/08/2022  19:23    <DIR>          files_for_lab
# 30/08/2022  11:44            70,268 LAB 2 r.ipynb
# 08/08/2022  19:23             1,097 readme.md
#                2 File(s)         71,365 bytes
#                5 Dir(s)  405,368,061,952 bytes free

# %%
cd lab-customer-analysis-round-2
# Out:
# [WinError 2] The system cannot find the file specified: 'lab-customer-analysis-round-2'
# C:\Users\tomil\lab-customer-analysis-round-2

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil\lab-customer-analysis-round-2\files_for_lab
#
# 08/08/2022  19:23    <DIR>          .
# 30/08/2022  15:50    <DIR>          ..
# 08/08/2022  19:23               273 about.md
# 08/08/2022  19:23    <DIR>          csv_files
# 08/08/2022  19:23    <DIR>          excel_files
#                1 File(s)            273 bytes
#                4 Dir(s)  405,362,446,336 bytes free

# %%
df = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df = df.drop(columns=["Customer"], axis=1)# dropping the customer columns,it is nt useful for the task.

# %%
df # rechecking the dataframe, to see if the colums has been dropped.
# Out:
#        Unnamed: 0       State  Customer Lifetime Value Response  Coverage  \
# 0               0     Arizona              4809.216960       No     Basic
# 1               1  California              2228.525238       No     Basic
# 2               2  Washington             14947.917300       No     Basic
# 3               3      Oregon             22332.439460      Yes  Extended
# 4               4      Oregon              9025.067525       No   Premium
# ...           ...         ...                      ...      ...       ...
# 10905       10905      Nevada             15563.369440       No   Premium
# 10906       10906      Oregon              5259.444853       No     Basic
# 10907       10907     Arizona             23893.304100       No  Extended
# 10908       10908  California             11971.977650       No   Premium
# 10909       10909         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# # Feature extraction

# %%
df_num=df.select_dtypes(include=np.number)
df_cat=df.select_dtypes(include=np.object)
# Out:
# C:\Users\tomil\AppData\Local\Temp\ipykernel_116648\4106151310.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_cat=df.select_dtypes(include=np.object)

# %%
for cat in df_cat:
    sns.boxenplot( x=df_cat[cat], y=df["Total Claim Amount"] )
    plt.show()

# %%
df_cat #categorical dataframe
# Out:
#             State Response  Coverage Education Effective To Date  \
# 0         Arizona       No     Basic   College           2/18/11
# 1      California       No     Basic   College           1/18/11
# 2      Washington       No     Basic  Bachelor           2/10/11
# 3          Oregon      Yes  Extended   College           1/11/11
# 4          Oregon       No   Premium  Bachelor           1/17/11
# ...           ...      ...       ...       ...               ...
# 10905      Nevada       No   Premium  Bachelor           1/19/11
# 10906      Oregon       No     Basic   College            1/6/11
# 10907     Arizona       No  Extended  Bachelor            2/6/11
# 10908  California       No   Premium   College           2/13/11
# 10909         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0             Employed      M      Suburban        Married  Corporate Auto
# ...

# %%
for cat in df_cat:
    print(cat)
    df_cat[cat].value_counts().plot(kind='bar')
    plt.show()
# Out:
# State
# Response
# Coverage
# Education
# Effective To Date
# EmploymentStatus
# Gender
# Location Code
# Marital Status
# Policy Type
# Policy
# Renew Offer Type
# Sales Channel
# Vehicle Class
# Vehicle Size
# Vehicle Type

# %%
for cat in df_cat:
    print(cat)
    print(df_cat[cat].value_counts(dropna=False)/len(df_cat))
    print("-------------")
# Out:
# State
# California    0.325573
# Oregon        0.266636
# Arizona       0.177544
# Nevada        0.091017
# Washington    0.081393
# NaN           0.057837
# Name: State, dtype: float64
# -------------
# Response
# No     0.807791
# Yes    0.134372
# NaN    0.057837
# Name: Response, dtype: float64
# -------------
# Coverage
# Basic       0.610449
# Extended    0.299267
# Premium     0.090284
# Name: Coverage, dtype: float64
# -------------
# Education
# Bachelor                0.299908
# College                 0.293676
# High School or Below    0.288359
# Master                  0.081302
# Doctor                  0.036755
# Name: Education, dtype: float64
# -------------
# Effective To Date
# 1/10/11    0.021907
# 1/27/11    0.021907
# 1/31/11    0.020532
# 1/17/11    0.020257
# 2/14/11    0.020257
# 1/26/11    0.020165
# 1/3/11     0.019798
# 1/19/11    0.019432
# 2/27/11    0.018790
# 1/28/11    0.018607
# 2/26/11    0.018515
# 1/20/11    0.018423
# 1/21/11    0.018240
# ...

# %%
df["Effective To Date"]= pd.to_datetime(df["Effective To Date"],errors= 'coerce')
df["Effective To Date"]=df["Effective To Date"].apply(lambda x: x.strftime('%B-%Y'))#changing it to year and month.
df["Effective To Date"]
# Out:
# 0        February-2011
# 1         January-2011
# 2        February-2011
# 3         January-2011
# 4         January-2011
#              ...
# 10905     January-2011
# 10906     January-2011
# 10907    February-2011
# 10908    February-2011
# 10909     January-2011
# Name: Effective To Date, Length: 10910, dtype: object

# %%
for cat in df_cat:
    sns.boxenplot( x=df["Effective To Date"], y=df["Total Claim Amount"] )
    plt.show()

# %%
#there is no differences, after checking with time variables
